# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://wisevoter.com/country-rankings/poorest-countries-in-the-world/'

page = requests.get(url)

soup = BeautifulSoup(page.text, 'html')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# ...

# %%
soup.find_all('table')[0]
# Out:
# <table class="shdb-on-page-table" id="shdb-on-page-table"><thead><tr><th>#</th><th>Country</th><th>GDP per capita</th><th>GNI per capita</th><th>Gini Coefficient</th><th>Poverty Rate</th></tr></thead><tbody><tr><td class="shdb-on-page-table-body-Rank">1</td><td class="shdb-on-page-table-body-Geo">Burundi</td><td class="shdb-on-page-table-body-Data" data-order="1">$237</td><td class="shdb-on-page-table-body-Data" data-order="169">$240</td><td class="shdb-on-page-table-body-Data" data-order="65">38.6</td><td class="shdb-on-page-table-body-Data" data-order="6">64.9%</td></tr><tr><td class="shdb-on-page-table-body-Rank">2</td><td class="shdb-on-page-table-body-Geo">Somalia</td><td class="shdb-on-page-table-body-Data" data-order="2">$446</td><td class="shdb-on-page-table-body-Data" data-order="168">$450</td><td class="shdb-on-page-table-body-Data" data-order="81">36.8</td><td class="shdb-on-page-table-body-Data" data-order="1000"></td></tr><tr><td class="shdb-on-page-table-body-Rank">3</t
# ...

# %%
soup.find('table id', class_ ='sorting sorting_asc')

# %%
table = soup.find_all('table')

# %%
print(table)
# Out:
# [<table class="shdb-on-page-table" id="shdb-on-page-table"><thead><tr><th>#</th><th>Country</th><th>GDP per capita</th><th>GNI per capita</th><th>Gini Coefficient</th><th>Poverty Rate</th></tr></thead><tbody><tr><td class="shdb-on-page-table-body-Rank">1</td><td class="shdb-on-page-table-body-Geo">Burundi</td><td class="shdb-on-page-table-body-Data" data-order="1">$237</td><td class="shdb-on-page-table-body-Data" data-order="169">$240</td><td class="shdb-on-page-table-body-Data" data-order="65">38.6</td><td class="shdb-on-page-table-body-Data" data-order="6">64.9%</td></tr><tr><td class="shdb-on-page-table-body-Rank">2</td><td class="shdb-on-page-table-body-Geo">Somalia</td><td class="shdb-on-page-table-body-Data" data-order="2">$446</td><td class="shdb-on-page-table-body-Data" data-order="168">$450</td><td class="shdb-on-page-table-body-Data" data-order="81">36.8</td><td class="shdb-on-page-table-body-Data" data-order="1000"></td></tr><tr><td class="shdb-on-page-table-body-Rank">3</
# ...

# %%
table = soup.find_all('th')

# %%
print(table)
# Out:
# [<th>#</th>, <th>Country</th>, <th>GDP per capita</th>, <th>GNI per capita</th>, <th>Gini Coefficient</th>, <th>Poverty Rate</th>]

# %%
world_titles = soup.find_all('th')

# %%
world_titles
# Out:
# [<th>#</th>,
#  <th>Country</th>,
#  <th>GDP per capita</th>,
#  <th>GNI per capita</th>,
#  <th>Gini Coefficient</th>,
#  <th>Poverty Rate</th>]

# %%
world_table_titles = [titles.text.strip() for titles in world_titles]

print(world_table_titles)
# Out:
# ['#', 'Country', 'GDP per capita', 'GNI per capita', 'Gini Coefficient', 'Poverty Rate']

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns = world_table_titles)

df
# Out:
# Empty DataFrame
# Columns: [#, Country, GDP per capita, GNI per capita, Gini Coefficient, Poverty Rate]
# Index: []

# %%
column_data = soup.find_all('tr')

# %%
for row in column_data[1:]:
    row_data = row.find_all('td')
    individual_row_data = [data.text.strip() for data in row_data]
    print(individual_row_data)
# Out:
# ['1', 'Burundi', '$237', '$240', '38.6', '64.9%']
# ['2', 'Somalia', '$446', '$450', '36.8', '']
# ['3', 'Mozambique', '$500', '$480', '54', '46.1%']
# ['4', 'Central African Republic', '$511', '$530', '56.2', '62%']
# ['5', 'Madagascar', '$515', '$500', '42.6', '70.7%']
# ['6', 'Sierra Leone', '$516', '$510', '35.7', '56.8%']
# ['7', 'Democratic Republic of the Congo', '$584', '$580', '42.1', '63.9%']
# ['8', 'Niger', '$595', '$590', '37.3', '40.8%']
# ['9', 'Malawi', '$643', '$630', '38.5', '51.5%']
# ['10', 'Liberia', '$673', '$620', '35.3', '50.9%']
# ['11', 'Yemen', '$691', '', '36.7', '48.6%']
# ['12', 'Chad', '$696', '$650', '37.5', '42.3%']
# ['13', 'Sudan', '$764', '$670', '34.2', '46.5%']
# ['14', 'Guinea-Bissau', '$813', '$780', '34.8', '69.3%']
# ['15', 'Rwanda', '$834', '$850', '43.7', '38.2%']
# ['16', 'The Gambia', '$836', '$800', '', '']
# ['17', 'Uganda', '$858', '$840', '42.7', '21.4%']
# ['18', 'Tajikistan', '$897', '$1,150', '34', '26.3%']
# ...

# %%
column_data = soup.find_all('tr')

# %%
for row in column_data[1:]:
    row_data = row.find_all('td')
    individual_row_data = [data.text.strip() for data in row_data]
    
    Length = len(df)
    df.loc[Length] = individual_row_data

# %%
df
# Out:
#        #                   Country GDP per capita GNI per capita  \
# 0      1                   Burundi           $237           $240
# 1      2                   Somalia           $446           $450
# 2      3                Mozambique           $500           $480
# 3      4  Central African Republic           $511           $530
# 4      5                Madagascar           $515           $500
# ..   ...                       ...            ...            ...
# 172  173                    Norway        $89,203        $84,090
# 173  174               Switzerland        $93,457        $90,360
# 174  175                   Ireland        $99,152        $74,520
# 175  176                   Bermuda       $110,869       $116,540
# 176  177                Luxembourg       $135,683
#
#     Gini Coefficient Poverty Rate
# 0               38.6        64.9%
# 1               36.8
# 2                 54        46.1%
# 3               56.2          62%
# 4               42.6        70.7%
# ...

# %%
df.to_csv(r'C:\Users\ogare\OneDrive\Desktop\Poorest_countries.csv', index = False)
